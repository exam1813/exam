# %%
from sklearn.cluster import KMeans

data_features = ["Hieght", "Age"]
x = [[165,19], [175,32], [136,35], [174, 65], [141, 28], [176,15], [131, 32], 
     [166,6], [128, 32], [179,10], [136,34], [186,20], [126,25], [176, 28], 
     [112, 38], [169,9], [171,36], [116,25], [196,25]]

model = KMeans(n_clusters=3)

# Fitting Model
model.fit(x)

# Printing Predictions
print(model.predict(x))

x1 = []  # hieght
x2 = []  # age
for item in x:
    x1.append(item[0])
    x2.append(item[1])

print(x1)
print(x2)

import matplotlib.pyplot as plt
plt.scatter(x1, x2, c=model.labels_)
# Out:
# [1 1 2 0 2 1 2 1 2 1 2 1 2 1 2 1 1 2 1]
# [165, 175, 136, 174, 141, 176, 131, 166, 128, 179, 136, 186, 126, 176, 112, 169, 171, 116, 196]
# [19, 32, 35, 65, 28, 15, 32, 6, 32, 10, 34, 20, 25, 28, 38, 9, 36, 25, 25]
# C:\Users\anjan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
